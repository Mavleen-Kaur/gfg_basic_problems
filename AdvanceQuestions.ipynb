# %%
# reversing while loop horizontaly
i = 4
n = 0
while n < i:

    j = 4
    m = 0
    while j > m:
        print(j,end = "")
        j-=1
    print()
    i -= 1
# Out:
# 4321
# 4321
# 4321
# 4321

# %%
i= 0
n =8
while i < n:

    j = 0
    m = 5
    while j < i :
        print(i, end="")
        j+=1
    print()
    i +=1
# Out:
# 1
# 22
# 333
# 4444
# 55555
# 666666
# 7777777

# %%
i= 1
n =8
while i < n:

    j = 0
    m = 5
    while j < i :
        print("*", end="")
        j+=1

    k = 0
    o = 5
    while k < o:
        print(k, end ="")
        k+=1
        
    print()
    i +=1
# Out:
# *01234
# **01234
# ***01234
# ****01234
# *****01234
# ******01234
# *******01234

# %%
i= 1
n =8
while i < n:

    j = 0
    m = 5
    while j < i :
        print(" ",end ="")
        j+=1

    k = 0
    o = 5
    while k < o:
        print(k, end ="")
        k+=1
        
    print()
    i +=1
# Out:
#  01234
#   01234
#    01234
#     01234
#      01234
#       01234
#        01234

# %%
n = 5
i= 0
while i <= n:
    m = 8
    j = 0
    while j <= m:
        if (i==0) or (i==n) or (j==0) or (j==m):
             print(j,end="")
        else:
             print(" ",end="")

        j+=1
    print()
    i+=1
# Out:
# 012345678
# 0       8
# 0       8
# 0       8
# 0       8
# 012345678

# %%
n = 5
i= 0
while i <= n:
    m = 8
    j = 0
    while j <= m:
        if (i==0) or (i==n) or (j==0) or (j==m):
             print("*",end="")
        else:
             print(" ",end="")

        j+=1
    print()
    i+=1
# Out:
# *********
# *       *
# *       *
# *       *
# *       *
# *********

# %%
m=0
n=8
while m<n:
    
    i=1
    j=6
    while i<m:
        print(m,end="")
        i+=1
    print()
    m+=1
# Out:
# 2
# 33
# 444
# 5555
# 66666
# 777777

# %%
m=0
n=6
while m<n:
    
    i = 0
    j = 4
    while i < m:
        print(j,end ="")
        j-=1
    print()
    n-=1

# %%
li = [4,7,2,1,5,8,6,9,3]

# %%
greatest = li[0]
i = 0
n = len(li)
while i < n:
    print(i,li[i])
    if li[i]> greatest:
        greatest= li[i]
    i+=1

print('greatest number in this list is',greatest)
# Out:
# 0 1
# 1 4
# 2 7
# 3 2
# 4 5
# 5 8
# 6 6
# 7 9
# 8 3
# greatest number in this list is 9

# %%
greatest = li[0]
i = 0
n = len(li)
while i < n:
    #print(i,li[i])
    if li[i]> greatest:
        greatest= li[i]
    i+=1

print('greatest number in this list is',greatest)
# Out:
# greatest number in this list is 9

# %%
smallest = li[0]
i= 0
n = len(li)
while i<n:
    #print(i,li[i])
    if li[i]<smallest:
        smallest=li[i]
    i+=1

print('smallest number in this list is',smallest)
# Out:
# smallest number in this list is 1

# %%
li=[]

# %%
smallest = None
i= 0
n = len(li)
while i<n:
    #print(i,li[i])
    if smallest is None:
        smallest=li[0]
    if li[i]<smallest:
        smallest=li[i]
    i+=1

print('smallest number in this list is',smallest)
# Out:
# smallest number in this list is None

# %%
li = [4,7,2,1,5,8,6,9,3]

# %%
smallest = None
i= 0
n = len(li)
while i<n:
    #print(i,li[i])
    if smallest is None:
        smallest=li[0]
    if li[i]<smallest:
        smallest=li[i]
    i+=1

print('smallest number in this list is',smallest)
# Out:
# smallest number in this list is 1

# %%
smallest = None
i= 0
n = len(li)
index= None
while i<n:
    #print(i,li[i])
    if smallest is None:
        smallest=li[0]
        index=i
    if li[i]<smallest:
        smallest=li[i]
        index=i
    i+=1

print('smallest number in this list is',smallest,'on',index,'index')
# Out:
# smallest number in this list is 1 on 3 index

# %%
li=[4,7,2,5,1,8,6,1,9,3]

# %%
i = 0
n = len(li)
index= None
while i<n:
    #print(i,li[i])
    if li[i]==6:
        index=i
    i+=1

print('6 is on index',index)
# Out:
# 6 is on index 6

# %%
a=6
i = 0
n = len(li)
while i<n:
    #print(i,li[i])
    if li[i]==6:
        print('index of a is',i)
        break        
    i+=1
# Out:
# index of a is 6

# %%
li=[]

# %%
# if list is empty
a=6
i = 0
n = len(li)
while i<n:
    #print(i,li[i])
    if li[i]==6:
        print('index of a is',i)
        break        
    i+=1
if not n:
    print('empty list')
# Out:
# empty list

# %%
li=[4,5,7,2,5,1,8,6,1,5,9,3]

# %%
#if element is missing or present number of times
a=5
i = 0
n = len(li)
ans= []
while i<n:
    #print(i,li[i])
    if li[i]==a:
        ans.append(i)        
    i+=1
if not n:
    print('empty list')
elif ans:
    print(ans)
else:
    print('item is not present in the list')
# Out:
# [1, 4, 9]

# %%
li
# Out:
# [4, 5, 7, 2, 5, 1, 8, 6, 1, 5, 9, 3]

# %%
#Bubble Sort
sort = False
while not sort:
    sort = True
    a= 0
    b= 1
    while b < len(li):
        if li[a]>li[b]:
            sort = False
            li[a],li[b]=li[b],li[a]
        a+=1
        b+=1
    print(li)
# Out:
# [1, 1, 2, 3, 4, 5, 5, 5, 6, 7, 8, 9]

# %%
li=[7,4,1,8,5,2,5,9,6,3]

# %%
i=0
n = len(li)
while i<n:
    #print(i,end=" ")
    j = i +1
    while j<n:
       # print(j,end="")
        if li[i]==li[j]:
            print('element',li[i],'is repeating at index',i,j)
        j+=1
    #print()    
    i+=1
# Out:
# element 5 is repeating at index 4 6
